# %%
courses = ["CS106A", "CS106B", "MATH51"]

# %%
print(courses[0])
# Out:
# CS106A

# %%
# prediction: error
print(courses[-1])
# Out:
# MATH51

# %%
# prediction: ["CS106A", "CS106B"]
print(courses[0:2])
# Out:
# ['CS106A', 'CS106B']

# %%
courses.append("CS109")

# %%
# prediction: 4
print(len(courses))
# Out:
# 4

# %%
print(courses)
# Out:
# ['CS106A', 'CS106B', 'MATH51', 'CS109']

# %%
grades = {"CS106A": "A", "CS106B": "A-"}

# %%
print(grades["CS106B"])
# Out:
# A-

# %%
grades["MATH51"] = "A"

# %%
# prediction: error
# print(grades["ECON1"])

# %%
list (grades.keys())
# Out:
# ['CS106A', 'CS106B', 'MATH51']

# %%
# prediction: ["A", "A-", "A"]
grades.values()
# Out:
# dict_values(['A', 'A-', 'A'])

# %%
# prediction: ["CS106A", "CS106B", "CS109"]
[c for c in courses if c.startswith("CS")]
# Out:
# ['CS106A', 'CS106B', 'CS109']

# %%
# objective: return lowercase
[c.lower() for c in courses if c.startswith("CS")]
# Out:
# ['cs106a', 'cs106b', 'cs109']
